# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df=pd.read_csv('C:/Users/Sri/Desktop/New folder/transactions.csv')
df.head(20)
# Out:
#     transaction_id  product_id           category        date
# 0                1      662685       Casual Dress  2017-10-01
# 1                2      154881       Casual Dress  2017-10-01
# 2                3      220036       Casual Dress  2017-10-01
# 3                4      220036       Casual Dress  2017-10-01
# 4                5      950839   Pullover Sweater  2017-10-01
# 5                6      711818   Pullover Sweater  2017-10-01
# 6                7      825129       Casual Dress  2017-10-01
# 7                8      881500   Pullover Sweater  2017-10-01
# 8                9      120069   Pullover Sweater  2017-10-01
# 9               10      935727  Sleeveless Blouse  2017-10-01
# 10              11       20987  Sleeveless Blouse  2017-10-01
# 11              12      790404   Pullover Sweater  2017-10-01
# 12              13      188834      Fleece Jacket  2017-10-01
# 13              14      704032       Casual Dress  2017-10-01
# ...

# %%
df.describe(include='all')
# Out:
#         transaction_id    product_id      category        date
# count     1.203105e+06  1.203105e+06       1203105     1203105
# unique             NaN           NaN             4         365
# top                NaN           NaN  Casual Dress  2018-02-06
# freq               NaN           NaN        776888        7497
# mean      6.015530e+05  5.609364e+05           NaN         NaN
# std       3.473066e+05  3.237540e+05           NaN         NaN
# min       1.000000e+00  1.000000e+00           NaN         NaN
# 25%       3.007770e+05  2.806000e+05           NaN         NaN
# 50%       6.015530e+05  5.609510e+05           NaN         NaN
# 75%       9.023290e+05  8.413120e+05           NaN         NaN
# max       1.203105e+06  1.121600e+06           NaN         NaN

# %%
df['month']=pd.DatetimeIndex(df['date']).month
df.tail()
# Out:
#          transaction_id  product_id          category        date  month
# 1203100         1203101      964150  Pullover Sweater  2018-09-30      9
# 1203101         1203102       55866  Pullover Sweater  2018-09-30      9
# 1203102         1203103      268421      Casual Dress  2018-09-30      9
# 1203103         1203104      393290      Casual Dress  2018-09-30      9
# 1203104         1203105     1105343      Casual Dress  2018-09-30      9

# %%
df['category'].value_counts().plot('bar')

# %%
df['month'].value_counts()
# Out:
# 2     138497
# 3     121324
# 5     114558
# 1     104302
# 10    100841
# 11     95251
# 7      92848
# 8      90111
# 6      89623
# 12     88130
# 4      88097
# 9      79523
# Name: month, dtype: int64

# %%
df['month'].value_counts().plot('bar')

# %%
plt.plot(z1,color='red',label='Real google stocks')
#plt.plot(predicted_price,color='blue',label='Predicted stock price')
plt.xlabel('time')
plt.ylabel('prices')
plt.legend()
plt.show()

# %%
x2=df['category']
x2.head()
x2.plot.bar()

# %%
x2=df[df['category']=='Casual Dress']
x2['category']=1
x3=x2[x2['month']==1]
a=x3.shape[0]
#x2['month'].value_counts()
#x2['category']=2
x3=x2[x2['month']==2]
b=x3.shape[0]
x3=x2[x2['month']==3]
c=x3.shape[0]
x3=x2[x2['month']==4]
d=x3.shape[0]
x3=x2[x2['month']==6]
e=x3.shape[0]
x3=x2[x2['month']==7]
f=x3.shape[0]
x3=x2[x2['month']==8]
g=x3.shape[0]
x3=x2[x2['month']==9]
h=x3.shape[0]
x3=x2[x2['month']==5]
i=x3.shape[0]
x3=x2[x2['month']==10]
j=x3.shape[0]
x3=x2[x2['month']==12]
l=x3.shape[0]
x3=x2[x2['month']==11]
k=x3.shape[0]
print(k,l,h,a,b,f,e,c,d,f)
# Out:
# 54334 52338 47438 66649 91162 62865 63372 82695 60434 62865
# C:\Users\Sri\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
x2=df[df['category']=='Pullover Sweater']
x2['category']=2
x3=x2[x2['month']==1]
a1=x3.shape[0]
#x2['month'].value_counts()
#x2['category']=2
x3=x2[x2['month']==2]
b1=x3.shape[0]
x3=x2[x2['month']==3]
c1=x3.shape[0]
x3=x2[x2['month']==4]
d1=x3.shape[0]
x3=x2[x2['month']==6]
e1=x3.shape[0]
x3=x2[x2['month']==7]
f1=x3.shape[0]
x3=x2[x2['month']==8]
g1=x3.shape[0]
x3=x2[x2['month']==9]
h1=x3.shape[0]
x3=x2[x2['month']==5]
i1=x3.shape[0]
x3=x2[x2['month']==10]
j1=x3.shape[0]
x3=x2[x2['month']==12]
l1=x3.shape[0]
x3=x2[x2['month']==11]
k1=x3.shape[0]
print(k1,l1,h1,a1,b1,f1,e1,c1,d1,f1)
# Out:
# 29354 24862 21243 22481 24109 15219 10356 20045 12886 15219
# C:\Users\Sri\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
x2=df[df['category']=='Sleeveless Blouse']
x2['category']=3
x3=x2[x2['month']==1]
a2=x3.shape[0]
#x2['month'].value_counts()
#x2['category']=2
x3=x2[x2['month']==2]
b2=x3.shape[0]
x3=x2[x2['month']==3]
c2=x3.shape[0]
x3=x2[x2['month']==4]
d2=x3.shape[0]
x3=x2[x2['month']==6]
e2=x3.shape[0]
x3=x2[x2['month']==7]
f2=x3.shape[0]
x3=x2[x2['month']==8]
g2=x3.shape[0]
x3=x2[x2['month']==9]
h2=x3.shape[0]
x3=x2[x2['month']==5]
i2=x3.shape[0]
x3=x2[x2['month']==10]
j2=x3.shape[0]
x3=x2[x2['month']==12]
l2=x3.shape[0]
x3=x2[x2['month']==11]
k2=x3.shape[0]
print(k2,l2,h2,a2,b2,f2,e2,c2,d2,f2)
# Out:
# 10918 10481 10197 14674 22752 14183 15559 18177 14516 14183
# C:\Users\Sri\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
x2=df[df['category']=='Fleece Jacket']
x2['category']=3
x3=x2[x2['month']==1]
a11=x3.shape[0]
#x2['month'].value_counts()
#x2['category']=2
x3=x2[x2['month']==2]
b11=x3.shape[0]
x3=x2[x2['month']==3]
c11=x3.shape[0]
x3=x2[x2['month']==4]
d11=x3.shape[0]
x3=x2[x2['month']==6]
e11=x3.shape[0]
x3=x2[x2['month']==7]
f11=x3.shape[0]
x3=x2[x2['month']==8]
g11=x3.shape[0]
x3=x2[x2['month']==9]
h11=x3.shape[0]
x3=x2[x2['month']==5]
i11=x3.shape[0]
x3=x2[x2['month']==10]
j11=x3.shape[0]
x3=x2[x2['month']==12]
l11=x3.shape[0]
x3=x2[x2['month']==11]
k11=x3.shape[0]
print(k11,l11,h11,a11,b11,f11,e11,c11,d11,f11)
# Out:
# C:\Users\Sri\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 645 449 645 498 474 581 336 407 261 581

# %%
data = [[a11,1],[b11,2],[c11,3],[d11,4],[e11,5],[f11,6],[g11,7],[h11,8],[i11,9],[j11,10],[k11,11],[l11,12]]
ss = pd.DataFrame(data,columns=['jackets','month'])
ss.head()
# Out:
#    jackets  month
# 0      498      1
# 1      474      2
# 2      407      3
# 3      261      4
# 4      336      5

# %%
sns.barplot(x='month',y='jackets',data=ss)
plt.xlabel('month')
plt.ylabel('no of jackets sold')
plt.title("no of jackets sold per month")
plt.show()

# %%
#x=x2['month']
y=x2['category'].value_counts()
ax=sns.barplot(x='month',y,data=x2)
ax.set_xlabel('month ')
ax.set_ylabel('')
#ax.set_yticklabels([human(item, 'M') for item in ax.get_yticks()])
plt.title('income per month')
plt.show()
# Out:
#   File "<ipython-input-35-6c20b2e2cff5>", line 3
#     ax=sns.barplot(x='month',y,data=x2)
#                             ^
# SyntaxError: positional argument follows keyword argument

# %%
x2=x2.drop('date',axis=1)
x2=x2.drop('transaction_id',axis=1)
x2=x2.drop('product_id',axis=1)

# %%
x2.head()
x2=x2.values

# %%
p1=df[df['month']==1].sample(n=11000)
p2=df[df['month']==2].sample(n=20000)
p3=df[df['month']==3].sample(n=15000)
p4=df[df['month']==4].sample(n=6500)
p5=df[df['month']==5].sample(n=13000)
p6=df[df['month']==6].sample(n=7000)
p7=df[df['month']==7].sample(n=9000)
p8=df[df['month']==8].sample(n=8000)
p9=df[df['month']==9].sample(n=6000)
p10=df[df['month']==10].sample(n=10000)
p11=df[df['month']==11].sample(n=9000)
p12=df[df['month']==12].sample(n=7000)

# %%
final=pd.concat([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12])
final['month'].value_counts()
# Out:
# 2     20000
# 3     15000
# 5     13000
# 1     11000
# 10    10000
# 11     9000
# 7      9000
# 8      8000
# 12     7000
# 6      7000
# 4      6500
# 9      6000
# Name: month, dtype: int64

# %%
final=final.drop(["date"],axis=1)
final=final.drop(["transaction_id"],axis=1)

# %%
final['month'].value_counts()
# Out:
# 2     20000
# 3     15000
# 5     13000
# 1     11000
# 10    10000
# 11     9000
# 7      9000
# 8      8000
# 12     7000
# 6      7000
# 4      6500
# 9      6000
# Name: month, dtype: int64

# %%
from sklearn.utils import shuffle
final=shuffle(final)
final.head()
# Out:
#          product_id          category  month
# 152167       265584      Casual Dress     11
# 524213       972442  Pullover Sweater      2
# 1109041      477300  Pullover Sweater      8
# 1050325     1051329      Casual Dress      8
# 1099895      755583      Casual Dress      8

# %%
from sklearn.preprocessing import LabelEncoder
lr=LabelEncoder()
df['category']=lr.fit_transform(df['category'])
df.head()
# Out:
#    transaction_id  product_id  category        date  month
# 0               1      662685         0  2017-10-01     10
# 1               2      154881         0  2017-10-01     10
# 2               3      220036         0  2017-10-01     10
# 3               4      220036         0  2017-10-01     10
# 4               5      950839         2  2017-10-01     10

# %%
x=final.iloc[:,[1,2]]
print(x.shape)
x.head()
# Out:
# (121500, 2)
#          category  month
# 152167          0     11
# 524213          2      2
# 1109041         2      8
# 1050325         0      8
# 1099895         0      8

# %%
x['month'].value_counts()
# Out:
# 2     20000
# 3     15000
# 5     13000
# 1     11000
# 10    10000
# 11     9000
# 7      9000
# 8      8000
# 12     7000
# 6      7000
# 4      6500
# 9      6000
# Name: month, dtype: int64

# %%
x1=x.values

# %%
a=df[df['category']=='Casual Dress']

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,15):
    kmeans=KMeans(n_clusters=i,init='k-means++',max_iter=1000,n_init=10,random_state=0)
    kmeans.fit(x1)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,15),wcss)
plt.title('elbow_method')
plt.xlabel('cluster size')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans=KMeans(n_clusters=3, init ='k-means++',max_iter=300,n_init=10,algorithm='elkan',random_state=0)
y=kmeans.fit_predict(x1)
y
# Out:
# array([0, 2, 1, ..., 0, 2, 1])

# %%
y=np.array(y).tolist()
type(y)
# Out:
# list

# %%
x['cluster']=y
x['cluster'].value_counts()
# Out:
# 2    52500
# 1    37000
# 0    32000
# Name: cluster, dtype: int64

# %%
z=x.iloc[:,2].values
z=z.reshape(-1,1)
z.shape
# Out:
# (121500, 1)

# %%
plt.scatter(x1[y==0,1],x1[y==0,0],s=50, c='red',label='mature')
plt.scatter(x1[y==1,1],x1[y==1,0],s=50, c='blue',label='standard')
plt.scatter(x1[y==2,1],x1[y==2,0],s=50, c='green',label='target')

plt.title('clusters of clients')
plt.xlabel('month')
plt.ylabel('category')

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
nm=MinMaxScaler(feature_range=(0,1))
x['cluster_score']=nm.fit_transform(z)
# Out:
# C:\Users\Sri\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
x.head(100)
# Out:
#          category  month  cluster  cluster_score
# 152167          0     11        0            0.0
# 524213          2      2        2            1.0
# 1109041         2      8        1            0.5
# 1050325         0      8        1            0.5
# 1099895         0      8        1            0.5
# 474814          0      2        2            1.0
# 565329          3      3        2            1.0
# 1035588         0      8        1            0.5
# 895492          0      6        1            0.5
# 768167          0      5        1            0.5
# 157956          0     11        0            0.0
# 174260          0     11        0            0.0
# 474049          0      2        2            1.0
# 684435          0      4        2            1.0
# 1005499         0      7        1            0.5
# 477720          3      2        2            1.0
# 1165502         0      9        0            0.0
# 455002          0      2        2            1.0
# ...

# %%
from sklearn.mixture import GMM
gmm = GMM(n_components=4).fit(x)
labels = gmm.predict(x)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-33-84e8896ef602> in <module>
# ----> 1 from sklearn.mixture import GMM
#       2 gmm = GMM(n_components=4).fit(x)
#       3 labels = gmm.predict(x)
#
# ImportError: cannot import name 'GMM' from 'sklearn.mixture' (C:\Users\Sri\Anaconda3\lib\site-packages\sklearn\mixture\__init__.py)

# %%
from sklearn.mixture import GaussianMixture

# %%
gmm = GaussianMixture(n_components=3,covariance_type='full').fit(x1)
labels = gmm.predict(x1)
labels
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=int64)

# %%
labels=np.array(labels).tolist()
type(labels)
# Out:
# list

# %%
x['gmm']=labels
x.head()
# Out:
#    category  month  cluster  cluster_score  gmm
# 0         0     10        2            1.0    2
# 1         0     10        2            1.0    2
# 2         0     10        2            1.0    2
# 3         0     10        2            1.0    2
# 4         2     10        2            1.0    2

# %%
z=x.iloc[:,2].values
z=z.reshape(-1,1)
z.shape
# Out:
# (1203105, 1)

# %%
nm=MinMaxScaler(feature_range=(0,1))
x['gmm_score']=nm.fit_transform(z)
# Out:
# C:\Users\Sri\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
x.tail(100)
# Out:
#          category  month  cluster  cluster_score  gmm  gmm_score
# 1203005         2      9        2            1.0    2        1.0
# 1203006         0      9        2            1.0    2        1.0
# 1203007         2      9        2            1.0    2        1.0
# 1203008         0      9        2            1.0    2        1.0
# 1203009         0      9        2            1.0    2        1.0
# 1203010         2      9        2            1.0    2        1.0
# 1203011         2      9        2            1.0    2        1.0
# 1203012         0      9        2            1.0    2        1.0
# 1203013         0      9        2            1.0    2        1.0
# 1203014         2      9        2            1.0    2        1.0
# 1203015         3      9        2            1.0    2        1.0
# 1203016         2      9        2            1.0    2        1.0
# 1203017         2      9        2            1.0    2        1.0
# ...

# %%
plt.scatter(x.iloc[:, 0], x.iloc[:, 1], c=labels, s=40, cmap='viridis');

# %%
p1=x[x['month']==1].sample(n=10000)
p1.head()
# Out:
#         category  month
# 292781         0      1
# 370456         3      1
# 331800         2      1
# 306454         3      1
# 317082         0      1

# %%
sum(df.isnull().any())
# Out:
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.25
 
# set height of bar
bars1 = [a,b,c,d,e,f,g,h,i,j,k,l]
bars2 = [a1,b1,c1,d1,e1,f1,g1,h1,i1,j1,k1,l1]
bars3 = [a11,b11,c11,d11,e11,f11,g11,h11,i11,j11,l11,k11]
bars4 = [a2,b2,c2,d2,e2,f2,g2,h2,i2,j2,k2,l2]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3] 
# Make the plot
plt.bar(r1, bars1, color='g', width=barWidth, edgecolor='white', label='Casual Dress')
plt.bar(r2, bars2, color='b', width=barWidth, edgecolor='white', label='Sleeveless Blouse')
plt.bar(r3, bars3, color='y', width=barWidth, edgecolor='white', label='Fleece Jacker')
plt.bar(r4, bars4, color='r', width=barWidth, edgecolor='white', label='Pullover Sweater')

 
# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], ['Jan', 'Feb', 'Mar', 'Apr', 'May','Jun','Jul','Aug','Sept','Oct','Nov','Dec'])
 
# Create legend & Show graphic
plt.legend()
plt.show()
